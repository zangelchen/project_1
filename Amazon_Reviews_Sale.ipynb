# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import json

# %%
music_list=[]
filepath_music = os.path.join("Digital_Music_5.json")
with open(filepath_music) as jsonfile:
    for line in jsonfile: 
        music_json=json.loads(line)
        music_list.append(music_json)
        
music_df = pd.DataFrame(music_list)
music_df
# Out:
#         overall vote  verified   reviewTime      reviewerID        asin  \
# 0           5.0    3      True   06 3, 2013  A2TYZ821XXK2YZ  3426958910
# 1           5.0  NaN      True  10 11, 2014  A3OFSREZADFUDY  3426958910
# 2           5.0  NaN      True  02 11, 2014  A2VAMODP8M77NG  3426958910
# 3           4.0    3     False   12 7, 2013   AAKSLZ9IDTEH0  3426958910
# 4           5.0  NaN      True  06 12, 2016  A3OH43OZJLKI09  5557706259
# ...         ...  ...       ...          ...             ...         ...
# 169776      5.0  NaN      True  08 19, 2018  A1SR2T84IXOMAQ  B01HJ91MTW
# 169777      5.0  NaN      True  03 18, 2018  A2SR3DWJR1PYR6  B01HJ91MTW
# 169778      5.0  NaN      True   03 7, 2018  A24V7X30NIMOIY  B01HJ91MTW
# 169779      5.0  NaN      True  02 12, 2018  A1LW10GYP2EYM1  B01HJ91MTW
# 169780      5.0  NaN      True  01 27, 2018  A26TH3YW0QWPI7  B01HJ91MTW
#
#                             style       reviewerName  \
# ...

# %%
meta_music=[]
i=0
filepath_metamusic = os.path.join("meta_Digital_Music.json")
with open(filepath_metamusic) as jsonfile:
    for line in jsonfile: 
        i+=1
        try: 
            music_json=json.loads(line)
            meta_music.append(music_json)
        except: 
            print(i)
            continue       
            
metamusic_df = pd.DataFrame(meta_music)
metamusic_df
# Out:
#       category tech1                                        description fit  \
# 0           []                                                       []
# 1           []                                                       []
# 2           []                                                       []
# 3           []                                                       []
# 4           []        [1. Losing Game 2. I Can't Wait 3. Didn't He S...
# ...        ...   ...                                                ...  ..
# 74342       []        [1. "Free At Last" Southside 1:21 2. "Never Go...
# 74343       []                                                       []
# 74344       []                                                       []
# 74345       []                                                       []
# 74346       []        [album 2016: 01.Autogram 02.Dobrotvorne svrhe ...
#
#                                                    title  \
# ...

# %%
cd_list=[]
filepath_cd = os.path.join("CDs_and_Vinyl_5.json")
with open(filepath_cd) as jsonfile:
    for line in jsonfile: 
        cd_json=json.loads(line)
        cd_list.append(cd_json)
        
cd_df = pd.DataFrame(music_list)
cd_df
# Out:
#         overall vote  verified   reviewTime      reviewerID        asin  \
# 0           5.0    3      True   06 3, 2013  A2TYZ821XXK2YZ  3426958910
# 1           5.0  NaN      True  10 11, 2014  A3OFSREZADFUDY  3426958910
# 2           5.0  NaN      True  02 11, 2014  A2VAMODP8M77NG  3426958910
# 3           4.0    3     False   12 7, 2013   AAKSLZ9IDTEH0  3426958910
# 4           5.0  NaN      True  06 12, 2016  A3OH43OZJLKI09  5557706259
# ...         ...  ...       ...          ...             ...         ...
# 169776      5.0  NaN      True  08 19, 2018  A1SR2T84IXOMAQ  B01HJ91MTW
# 169777      5.0  NaN      True  03 18, 2018  A2SR3DWJR1PYR6  B01HJ91MTW
# 169778      5.0  NaN      True   03 7, 2018  A24V7X30NIMOIY  B01HJ91MTW
# 169779      5.0  NaN      True  02 12, 2018  A1LW10GYP2EYM1  B01HJ91MTW
# 169780      5.0  NaN      True  01 27, 2018  A26TH3YW0QWPI7  B01HJ91MTW
#
#                             style       reviewerName  \
# ...

# %%
meta_cd=[]
i=0
filepath_metacd = os.path.join("meta_CDs_and_Vinyl.json")
with open(filepath_metacd) as jsonfile:
    for line in jsonfile: 
        i+=1
        try: 
            cd_json=json.loads(line)
            meta_cd.append(cd_json)
        except: 
            print(i)
            continue       
            
metacd_df = pd.DataFrame(meta_music)
metacd_df
# Out:
#       category tech1                                        description fit  \
# 0           []                                                       []
# 1           []                                                       []
# 2           []                                                       []
# 3           []                                                       []
# 4           []        [1. Losing Game 2. I Can't Wait 3. Didn't He S...
# ...        ...   ...                                                ...  ..
# 74342       []        [1. "Free At Last" Southside 1:21 2. "Never Go...
# 74343       []                                                       []
# 74344       []                                                       []
# 74345       []                                                       []
# 74346       []        [album 2016: 01.Autogram 02.Dobrotvorne svrhe ...
#
#                                                    title  \
# ...

# %%
merging_dig_df = pd.merge(metamusic_df, music_df, on="asin", how="outer")
pd.options.display.max_columns = None
merging_dig_df
# Out:
#        category tech1                                        description  fit  \
# 0            []                                                       []
# 1            []                                                       []
# 2            []                                                       []
# 3            []                                                       []
# 4            []        [1. Losing Game 2. I Can't Wait 3. Didn't He S...
# ...         ...   ...                                                ...  ...
# 243981      NaN   NaN                                                NaN  NaN
# 243982      NaN   NaN                                                NaN  NaN
# 243983      NaN   NaN                                                NaN  NaN
# 243984      NaN   NaN                                                NaN  NaN
# 243985      NaN   NaN                                                NaN  NaN
#
#                                     title  \
# ...

# %%
price_df=merging_dig_df[['brand','price','overall']]
price_df
# Out:
#                          brand   price  overall
# 0          John Michael Talbot  $18.99      NaN
# 1       Second Chapter of Acts              NaN
# 2                Don Francisco              NaN
# 3                  Keith Green  $13.01      NaN
# 4                  Dallas Holm              NaN
# ...                        ...     ...      ...
# 243981                     NaN     NaN      4.0
# 243982                     NaN     NaN      5.0
# 243983                     NaN     NaN      4.0
# 243984                     NaN     NaN      5.0
# 243985                     NaN     NaN      5.0
#
# [243986 rows x 3 columns]

# %%
NaN_df = price_df.replace('',np.nan,regex = True)
price1_df=NaN_df.replace('\n',np.nan,regex=True)
price2_df=price1_df.replace('.a-section.a-spacing-mini{margin-bottom:6px!im...',np.nan,regex=True)
price3_df=price2_df.replace('.a-box-inner{background-color:#fff}#alohaBuyBo...',np.nan,regex=True)
price_df=price3_df.dropna()
price_df
# Out:
#                 brand   price  overall
# 474    Casting Crowns  $16.98      5.0
# 475    Casting Crowns  $16.98      4.0
# 476    Casting Crowns  $16.98      5.0
# 477    Casting Crowns  $16.98      5.0
# 478    Casting Crowns  $16.98      5.0
# ...               ...     ...      ...
# 76179           Ghost  $23.90      4.0
# 76180           Ghost  $23.90      5.0
# 76181           Ghost  $23.90      5.0
# 76182           Ghost  $23.90      3.0
# 76183           Ghost  $23.90      1.0
#
# [1523 rows x 3 columns]

# %%
price_df.sort_values(by=['price'],ascending=False).head()
# Out:
#                        brand   price  overall
# 36047         Paul Englishby  $99.10      5.0
# 36046         Paul Englishby  $99.10      5.0
# 23990  101 Strings Orchestra  $99.00      5.0
# 23984  101 Strings Orchestra  $99.00      5.0
# 23986  101 Strings Orchestra  $99.00      5.0

# %%
price_df.sort_values(by=['price'],ascending=True).head()
# Out:
#           brand  price  overall
# 33890  Gershwin  $0.98      3.0
# 33879  Gershwin  $0.98      5.0
# 33880  Gershwin  $0.98      4.0
# 33881  Gershwin  $0.98      4.0
# 33882  Gershwin  $0.98      4.0

# %%
total_brand_sales=price_df.groupby('brand').sum()['price']
total_brand_sales
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'price'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
plt.scatter(price_df['price'], price_df['overall'], color = "blue")
plt.xlabel("overall")
plt.ylabel("price")
plt.title("price vs Rating")
plt.show()
